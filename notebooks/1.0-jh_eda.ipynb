# %%
import pandas as pd
import numpy as np
import altair as alt
import os

# %load_ext autoreload
# %autoreload 2

alt.data_transformers.enable('data_server')
alt.renderers.enable('mimetype')
# Out:
# RendererRegistry.enable('mimetype')

# %%
discussions = pd.read_csv(os.path.join(os.pardir, "data", "additional", "discussions.csv"))
discussions.describe()
# Out:
#        discussion_topic_message_length  post_message_length  count_of_likes
# count                      1611.000000          1611.000000     1611.000000
# mean                        917.047796          1079.855990        0.219739
# std                         433.600259           952.027795        0.540423
# min                          79.000000             0.000000        0.000000
# 25%                         611.000000           402.000000        0.000000
# 50%                         783.000000           785.000000        0.000000
# 75%                        1369.000000          1475.000000        0.000000
# max                        2359.000000          6298.000000        7.000000

# %%
discussions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   actor_id                         1611 non-null   object
#  1   membership_role                  1611 non-null   object
#  2   timestamp                        1611 non-null   object
#  3   post_id                          1611 non-null   object
#  4   post_parent_id                   1611 non-null   object
#  5   discussion_topic_title           1611 non-null   object
#  6   discussion_topic_id              1611 non-null   object
#  7   discussion_topic_message_length  1611 non-null   int64
#  8   post_message_length              1611 non-null   int64
#  9   count_of_likes                   1611 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 126.0+ KB

# %%
discussions_topics = pd.read_csv(os.path.join(os.pardir, "data", "additional", "discussion_topics.csv"))

discussions_topics.describe()
# Out:
#        position  lock_at  discussion_subentry_count  podcast_url
# count  6.000000      0.0                  19.000000          0.0
# mean   3.500000      NaN                   2.473684          NaN
# std    1.870829      NaN                   8.342451          NaN
# min    1.000000      NaN                   0.000000          NaN
# 25%    2.250000      NaN                   0.000000          NaN
# 50%    3.500000      NaN                   0.000000          NaN
# 75%    4.750000      NaN                   0.000000          NaN
# max    6.000000      NaN                  35.000000          NaN

# %%
discussions
# Out:
#         actor_id membership_role                  timestamp  \
# 0     INSTRUCTOR  ["Instructor"]  2033-01-18 17:13:01+00:00
# 1     INSTRUCTOR  ["Instructor"]  2033-01-18 17:13:02+00:00
# 2      LEARNER_3     ["Learner"]  2033-01-28 06:55:40+00:00
# 3     LEARNER_11     ["Learner"]  2033-01-29 01:04:32+00:00
# 4      LEARNER_3     ["Learner"]  2033-01-29 05:54:31+00:00
# ...          ...             ...                        ...
# 1606  LEARNER_19     ["Learner"]  2033-03-23 15:59:20+00:00
# 1607  INSTRUCTOR  ["Instructor"]  2033-03-24 09:51:33+00:00
# 1608  LEARNER_14     ["Learner"]  2033-03-24 10:01:51+00:00
# 1609   LEARNER_2     ["Learner"]  2033-03-26 16:10:40+00:00
# 1610  INSTRUCTOR  ["Instructor"]  2033-03-26 16:13:06+00:00
#
#                                post_id                    post_parent_id  \
# 0     e29fca96e5557a20cabec778dc885345  1e1288fa5e19f13c45b0231e8cbedab6
# 1     cf6816ae103ab5e2c82d6595eb49e02e  1e1288fa5e19f13c45b0231e8cbedab6
# 2     abb6c24171f8b195cf0d050858e4ff18  cf6816ae103ab5e2c82d6595eb49e02e
# 3     a250f9cde1c58d4dba3d4f918e82a018  abb6c24171f8b195cf0d050858e4ff18
# 4     3ac8537702d3d7d8bf033d73a4491591  a250f9cde1c58d4dba3d4f918e82a018
# ...                                ...                               ...
# 1606  7a91b20369b9853e87f56d13600bb2a5  d6fe64dc8c4e1ede591ff45a98e7255c
# 1607  ed80eb6d2d9f9f86fec336142fb849af  d6fe64dc8c4e1ede591ff45a98e7255c
# 1608  a1210d7d04b9dc8555f53e773af18a28  d6fe64dc8c4e1ede591ff45a98e7255c
# 1609  d6d1a9d82c7fa0226e012984b81c0e41  d6fe64dc8c4e1ede591ff45a98e7255c
# 1610  87f85da1a493130f74f138560e60c81c  d6d1a9d82c7fa0226e012984b81c0e41
#
#              discussion_topic_title               discussion_topic_id  \
# 0     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 1     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 2     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 3     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 4     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# ...                             ...                               ...
# 1606         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
# 1607         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
# 1608         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
# 1609         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
# 1610         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
#
#       discussion_topic_message_length  post_message_length  count_of_likes
# 0                                 367                    0               0
# 1                                  79                    0               0
# 2                                  79                  564               0
# 3                                  79                  174               0
# 4                                  79                  226               0
# ...                               ...                  ...             ...
# 1606                              332                 1100               0
# 1607                              332                  111               0
# 1608                              332                  611               0
# 1609                              332                  237               0
# 1610                              332                   36               0
#
# [1611 rows x 10 columns]

# %%
disc_merged = pd.merge(discussions_topics, discussions, how = "inner", left_on = 'id', right_on = 'discussion_topic_id')

disc_merged
# Out:
#                                     id                          title  \
# 0     132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# 1     132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# 2     132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# 3     132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# 4     132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# ...                                ...                            ...
# 1606  a475fae949c627a4125abbfcf0faeaa8                    Casual Area
# 1607  a475fae949c627a4125abbfcf0faeaa8                    Casual Area
# 1608  a475fae949c627a4125abbfcf0faeaa8                    Casual Area
# 1609  a475fae949c627a4125abbfcf0faeaa8                    Casual Area
# 1610  a475fae949c627a4125abbfcf0faeaa8                    Casual Area
#
#       position  podcast_has_student_posts discussion_type  lock_at  \
# 0          NaN                      False        threaded      NaN
# 1          NaN                      False        threaded      NaN
# 2          NaN                      False        threaded      NaN
# 3          NaN                      False        threaded      NaN
# 4          NaN                      False        threaded      NaN
# ...        ...                        ...             ...      ...
# 1606       2.0                      False        threaded      NaN
# 1607       2.0                      False        threaded      NaN
# 1608       2.0                      False        threaded      NaN
# 1609       2.0                      False        threaded      NaN
# 1610       2.0                      False        threaded      NaN
#
#       allow_rating  discussion_subentry_count  podcast_url read_state  ...  \
# 0             True                          0          NaN       read  ...
# 1             True                          0          NaN       read  ...
# 2             True                          0          NaN       read  ...
# 3             True                          0          NaN       read  ...
# 4             True                          0          NaN       read  ...
# ...            ...                        ...          ...        ...  ...
# 1606          True                         35          NaN       read  ...
# 1607          True                         35          NaN       read  ...
# 1608          True                         35          NaN       read  ...
# 1609          True                         35          NaN       read  ...
# 1610          True                         35          NaN       read  ...
#
#         actor_id  membership_role                  timestamp  \
# 0     INSTRUCTOR   ["Instructor"]  2033-01-18 17:13:01+00:00
# 1     INSTRUCTOR   ["Instructor"]  2033-01-18 17:13:02+00:00
# 2      LEARNER_3      ["Learner"]  2033-01-28 06:55:40+00:00
# 3     LEARNER_11      ["Learner"]  2033-01-29 01:04:32+00:00
# 4      LEARNER_3      ["Learner"]  2033-01-29 05:54:31+00:00
# ...          ...              ...                        ...
# 1606   LEARNER_3      ["Learner"]  2033-03-29 06:04:58+00:00
# 1607   LEARNER_2      ["Learner"]  2033-03-26 14:36:55+00:00
# 1608  INSTRUCTOR   ["Instructor"]  2033-03-23 15:14:07+00:00
# 1609  INSTRUCTOR   ["Instructor"]  2033-03-30 15:41:49+00:00
# 1610  LEARNER_14      ["Learner"]  2033-04-24 15:29:53+00:00
#
#                                post_id                    post_parent_id  \
# 0     e29fca96e5557a20cabec778dc885345  1e1288fa5e19f13c45b0231e8cbedab6
# 1     cf6816ae103ab5e2c82d6595eb49e02e  1e1288fa5e19f13c45b0231e8cbedab6
# 2     abb6c24171f8b195cf0d050858e4ff18  cf6816ae103ab5e2c82d6595eb49e02e
# 3     a250f9cde1c58d4dba3d4f918e82a018  abb6c24171f8b195cf0d050858e4ff18
# 4     3ac8537702d3d7d8bf033d73a4491591  a250f9cde1c58d4dba3d4f918e82a018
# ...                                ...                               ...
# 1606  0025391a94a97edd973d15a259d4cf5f  ac05e4c10a8ded61383c93d5cb402616
# 1607  a568e25addefdb085d4d758eb74a5b1d  8b7aec0250007bba401fc2ca1855a074
# 1608  366a394a89d814e4ef347bc777dfce9e  e5de10d02b5e478fce4fab58dd02585b
# 1609  1e16dfecb313ded5428d66a9d7668b06  e5de10d02b5e478fce4fab58dd02585b
# 1610  8f5736bba6ab39b8d8fab4b97f383445  e5de10d02b5e478fce4fab58dd02585b
#
#              discussion_topic_title               discussion_topic_id  \
# 0     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 1     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 2     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 3     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 4     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# ...                             ...                               ...
# 1606                    Casual Area  a475fae949c627a4125abbfcf0faeaa8
# 1607                    Casual Area  a475fae949c627a4125abbfcf0faeaa8
# 1608                    Casual Area  a475fae949c627a4125abbfcf0faeaa8
# 1609                    Casual Area  a475fae949c627a4125abbfcf0faeaa8
# 1610                    Casual Area  a475fae949c627a4125abbfcf0faeaa8
#
#      discussion_topic_message_length post_message_length count_of_likes
# 0                                367                   0              0
# 1                                 79                   0              0
# 2                                 79                 564              0
# 3                                 79                 174              0
# 4                                 79                 226              0
# ...                              ...                 ...            ...
# 1606                             223                 611              1
# 1607                             223                1021              1
# 1608                             223                 527              0
# 1609                             223                 174              2
# 1610                             223                 646              0
#
# [1611 rows x 23 columns]

# %%
grades = pd.read_csv(os.path.join(os.pardir, "data", "additional", "gradebook.csv"))

# get list of column names
grade_cols = list(grades.columns)

# subset of cols we want
grade_cols_incldue = ['Student',
 'Assignment 1 Current Score',
 'Assignment 2 Current Score',
 'Assignment 3 Current Score',
 'Participation & engagement Current Score',
 'Current Score']

# grades df to merge, drops first two rows as they do not contain important info 
grade_merge = grades[grade_cols_incldue].drop([0,1]).reset_index(drop=True)

# %%
module_items = pd.read_csv(os.path.join(os.pardir, "data", "additional", "module_items.csv"))

module_discussions = module_items[['title', 'module_id', 'module_name']]

disc_merged2 = pd.merge(disc_merged, module_discussions, how = 'left', on = 'title')

full_table = pd.merge(disc_merged2, grade_merge, how = 'left', left_on = 'actor_id', right_on = 'Student')
full_table.head()
# Out:
#                                  id                          title  position  \
# 0  132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum       NaN
# 1  132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum       NaN
# 2  132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum       NaN
# 3  132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum       NaN
# 4  132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum       NaN
#
#    podcast_has_student_posts discussion_type  lock_at  allow_rating  \
# 0                      False        threaded      NaN          True
# 1                      False        threaded      NaN          True
# 2                      False        threaded      NaN          True
# 3                      False        threaded      NaN          True
# 4                      False        threaded      NaN          True
#
#    discussion_subentry_count  podcast_url read_state  ...  \
# 0                          0          NaN       read  ...
# 1                          0          NaN       read  ...
# 2                          0          NaN       read  ...
# 3                          0          NaN       read  ...
# 4                          0          NaN       read  ...
#
#    post_message_length  count_of_likes module_id module_name     Student  \
# 0                    0               0       NaN         NaN         NaN
# 1                    0               0       NaN         NaN         NaN
# 2                  564               0       NaN         NaN   LEARNER_3
# 3                  174               0       NaN         NaN  LEARNER_11
# 4                  226               0       NaN         NaN   LEARNER_3
#
#   Assignment 1 Current Score Assignment 2 Current Score  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                         94                         92
# 3                         90                         79
# 4                         94                         92
#
#   Assignment 3 Current Score Participation & engagement Current Score  \
# 0                        NaN                                      NaN
# 1                        NaN                                      NaN
# 2                         82                                       90
# 3                         82                                       90
# 4                         82                                       90
#
#   Current Score
# 0           NaN
# 1           NaN
# 2            89
# 3          84.3
# 4            89
#
# [5 rows x 31 columns]

# %%
# likes per learner

alt.Chart(disc_merged).mark_bar().encode(
    alt.Y('actor_id', sort='x'),
    alt.X('count_of_likes')
)
# Out:
# /Users/jonah/opt/miniconda3/envs/571/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# post length per disscussion topic

alt.Chart(full_table).mark_bar().encode(
    alt.X('post_message_length'),
    alt.Y('title'),
    alt.Color('post_message_length')).facet('actor_id', columns=3)
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
