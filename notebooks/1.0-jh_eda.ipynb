# %%
import pandas as pd
import numpy as np
import altair as alt
import os
import scipy
# %load_ext autoreload
# %autoreload 2

alt.data_transformers.enable('data_server')
alt.renderers.enable('mimetype')
# Out:
# RendererRegistry.enable('mimetype')

# %%
disc_events = pd.read_csv(os.path.join(os.pardir, "data", "additional", "discussions.csv"))
disc_events.describe()
# Out:
#        discussion_topic_message_length  post_message_length  count_of_likes
# count                      1611.000000          1611.000000     1611.000000
# mean                        917.047796          1079.855990        0.219739
# std                         433.600259           952.027795        0.540423
# min                          79.000000             0.000000        0.000000
# 25%                         611.000000           402.000000        0.000000
# 50%                         783.000000           785.000000        0.000000
# 75%                        1369.000000          1475.000000        0.000000
# max                        2359.000000          6298.000000        7.000000

# %%
disc_topics = pd.read_csv(os.path.join(os.pardir, "data", "additional", "discussion_topics.csv"))

disc_topics = disc_topics[['id', 'title', 'todo_date_date']]

disc_topics.describe()
# Out:
#                                       id                          title  \
# count                                 19                             19
# unique                                19                             19
# top     132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# freq                                   1                              1
#
#                    todo_date_date
# count                          14
# unique                         13
# top     2033-02-12 20:06:09+00:00
# freq                            2

# %%
disc_topics = pd.read_csv(os.path.join(os.pardir, "data", "additional", "discussion_topics.csv"))
disc_topics = disc_topics[['id', 'title', 'todo_date_date']]


disc_merged = pd.merge(disc_topics, disc_events, how = "outer", left_on = 'id', right_on = 'discussion_topic_id')

disc_merged
# Out:
#                                     id                                 title  \
# 0     132f3fab56d60839d727b966a76c1b1e         Assignment 1 Discussion forum
# 1     132f3fab56d60839d727b966a76c1b1e         Assignment 1 Discussion forum
# 2     132f3fab56d60839d727b966a76c1b1e         Assignment 1 Discussion forum
# 3     132f3fab56d60839d727b966a76c1b1e         Assignment 1 Discussion forum
# 4     132f3fab56d60839d727b966a76c1b1e         Assignment 1 Discussion forum
# ...                                ...                                   ...
# 1609  a475fae949c627a4125abbfcf0faeaa8                           Casual Area
# 1610  a475fae949c627a4125abbfcf0faeaa8                           Casual Area
# 1611  a475fae949c627a4125abbfcf0faeaa8                           Casual Area
# 1612  a475fae949c627a4125abbfcf0faeaa8                           Casual Area
# 1613  5140d6a41e913754246127780ae01505  Q&A about the course and assignments
#
#      todo_date_date    actor_id membership_role                  timestamp  \
# 0               NaN  INSTRUCTOR  ["Instructor"]  2033-01-18 17:13:01+00:00
# 1               NaN  INSTRUCTOR  ["Instructor"]  2033-01-18 17:13:02+00:00
# 2               NaN   LEARNER_3     ["Learner"]  2033-01-28 06:55:40+00:00
# 3               NaN  LEARNER_11     ["Learner"]  2033-01-29 01:04:32+00:00
# 4               NaN   LEARNER_3     ["Learner"]  2033-01-29 05:54:31+00:00
# ...             ...         ...             ...                        ...
# 1609            NaN   LEARNER_2     ["Learner"]  2033-03-26 14:36:55+00:00
# 1610            NaN  INSTRUCTOR  ["Instructor"]  2033-03-23 15:14:07+00:00
# 1611            NaN  INSTRUCTOR  ["Instructor"]  2033-03-30 15:41:49+00:00
# 1612            NaN  LEARNER_14     ["Learner"]  2033-04-24 15:29:53+00:00
# 1613            NaN         NaN             NaN                        NaN
#
#                                post_id                    post_parent_id  \
# 0     e29fca96e5557a20cabec778dc885345  1e1288fa5e19f13c45b0231e8cbedab6
# 1     cf6816ae103ab5e2c82d6595eb49e02e  1e1288fa5e19f13c45b0231e8cbedab6
# 2     abb6c24171f8b195cf0d050858e4ff18  cf6816ae103ab5e2c82d6595eb49e02e
# 3     a250f9cde1c58d4dba3d4f918e82a018  abb6c24171f8b195cf0d050858e4ff18
# 4     3ac8537702d3d7d8bf033d73a4491591  a250f9cde1c58d4dba3d4f918e82a018
# ...                                ...                               ...
# 1609  a568e25addefdb085d4d758eb74a5b1d  8b7aec0250007bba401fc2ca1855a074
# 1610  366a394a89d814e4ef347bc777dfce9e  e5de10d02b5e478fce4fab58dd02585b
# 1611  1e16dfecb313ded5428d66a9d7668b06  e5de10d02b5e478fce4fab58dd02585b
# 1612  8f5736bba6ab39b8d8fab4b97f383445  e5de10d02b5e478fce4fab58dd02585b
# 1613                               NaN                               NaN
#
#              discussion_topic_title               discussion_topic_id  \
# 0     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 1     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 2     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 3     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 4     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# ...                             ...                               ...
# 1609                    Casual Area  a475fae949c627a4125abbfcf0faeaa8
# 1610                    Casual Area  a475fae949c627a4125abbfcf0faeaa8
# 1611                    Casual Area  a475fae949c627a4125abbfcf0faeaa8
# 1612                    Casual Area  a475fae949c627a4125abbfcf0faeaa8
# 1613                            NaN                               NaN
#
#       discussion_topic_message_length  post_message_length  count_of_likes
# 0                               367.0                  0.0             0.0
# 1                                79.0                  0.0             0.0
# 2                                79.0                564.0             0.0
# 3                                79.0                174.0             0.0
# 4                                79.0                226.0             0.0
# ...                               ...                  ...             ...
# 1609                            223.0               1021.0             1.0
# 1610                            223.0                527.0             0.0
# 1611                            223.0                174.0             2.0
# 1612                            223.0                646.0             0.0
# 1613                              NaN                  NaN             NaN
#
# [1614 rows x 13 columns]

# %%
grades = pd.read_csv(os.path.join(os.pardir, "data", "additional", "gradebook.csv"))

# get list of column names
grade_cols = list(grades.columns)

# subset of cols we want
grade_cols_incldue = ['Student',
 'Assignment 1 Current Score',
 'Assignment 2 Current Score',
 'Assignment 3 Current Score',
 'Participation & engagement Current Score',
 'Current Score']

# grades df to merge, drops first two rows as they do not contain important info 
grade_merge = grades[grade_cols_incldue].drop([0,1]).reset_index(drop=True)

# %%
module_items = pd.read_csv(os.path.join(os.pardir, "data", "additional", "module_items.csv"))

module_discussions = module_items[['title', 'module_id', 'module_name']]

disc_merged2 = pd.merge(disc_merged, module_discussions, how = 'left', on = 'title')

full_table = pd.merge(disc_merged2, grade_merge, how = 'inner', left_on = 'actor_id', right_on = 'Student')
full_table['timestamp'] = pd.to_datetime(full_table['timestamp'])
full_table['Current Score'] = full_table['Current Score'].astype(float)

full_table.head()
# Out:
#                                  id                          title  \
# 0  132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# 1  132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# 2  132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# 3  132f3fab56d60839d727b966a76c1b1e  Assignment 1 Discussion forum
# 4  e1f90c16c123e0f96b2af7d94a1c335c             Introduce yourself
#
#               todo_date_date   actor_id membership_role  \
# 0                        NaN  LEARNER_3     ["Learner"]
# 1                        NaN  LEARNER_3     ["Learner"]
# 2                        NaN  LEARNER_3     ["Learner"]
# 3                        NaN  LEARNER_3     ["Learner"]
# 4  2033-01-15 20:06:09+00:00  LEARNER_3     ["Learner"]
#
#                   timestamp                           post_id  \
# 0 2033-01-28 06:55:40+00:00  abb6c24171f8b195cf0d050858e4ff18
# 1 2033-01-29 05:54:31+00:00  3ac8537702d3d7d8bf033d73a4491591
# 2 2033-02-25 08:02:17+00:00  4b399c6443b76327cda3cf5cca76441a
# 3 2033-02-25 08:03:05+00:00  8e41a53c2213fc897bce39b56d59ddd4
# 4 2033-01-10 13:20:12+00:00  45ba74eafbac3a413fbcf903bbf3ba2e
#
#                      post_parent_id         discussion_topic_title  \
# 0  cf6816ae103ab5e2c82d6595eb49e02e  Assignment 1 Discussion forum
# 1  a250f9cde1c58d4dba3d4f918e82a018  Assignment 1 Discussion forum
# 2  108d12eb22a137b729bfa773f70df5b2  Assignment 1 Discussion forum
# 3  71b73cc230589c4a8991dcaed3ce53c2  Assignment 1 Discussion forum
# 4  05fbad9bf011e3f22026af152329e25b             Introduce yourself
#
#                 discussion_topic_id  ...  post_message_length  count_of_likes  \
# 0  132f3fab56d60839d727b966a76c1b1e  ...                564.0             0.0
# 1  132f3fab56d60839d727b966a76c1b1e  ...                226.0             0.0
# 2  132f3fab56d60839d727b966a76c1b1e  ...                 58.0             0.0
# 3  132f3fab56d60839d727b966a76c1b1e  ...                 98.0             0.0
# 4  e1f90c16c123e0f96b2af7d94a1c335c  ...                245.0             0.0
#
#                           module_id              module_name    Student  \
# 0                               NaN                      NaN  LEARNER_3
# 1                               NaN                      NaN  LEARNER_3
# 2                               NaN                      NaN  LEARNER_3
# 3                               NaN                      NaN  LEARNER_3
# 4  0347a47759cd8e24b01a5a76fe965be9  Week 1: Getting started  LEARNER_3
#
#   Assignment 1 Current Score Assignment 2 Current Score  \
# 0                         94                         92
# 1                         94                         92
# 2                         94                         92
# 3                         94                         92
# 4                         94                         92
#
#   Assignment 3 Current Score Participation & engagement Current Score  \
# 0                         82                                       90
# 1                         82                                       90
# 2                         82                                       90
# 3                         82                                       90
# 4                         82                                       90
#
#   Current Score
# 0          89.0
# 1          89.0
# 2          89.0
# 3          89.0
# 4          89.0
#
# [5 rows x 21 columns]

# %%
full_table.groupby('title')['todo_date_date'].unique()
# Out:
# title
# Assignment 1 Discussion forum                                                                    [nan]
# Casual Area                                                                                      [nan]
# Discussion 10: Reflections on eLearning readiness                          [2033-03-26 19:06:09+00:00]
# Discussion 11: Reflections on eLearning implementation strategies          [2033-04-02 19:06:09+00:00]
# Discussion 12: Analysis and comparison of approaches to eLearning          [2033-04-09 19:06:09+00:00]
# Discussion 1: The meaning of eLearning                                     [2033-01-22 20:06:09+00:00]
# Discussion 2: Reflect on rationales for eLearning                          [2033-01-29 20:05:10+00:00]
# Discussion 3: Funding issues                                               [2033-02-05 20:06:09+00:00]
# Discussion 4: Examples of faculty development for eLearning readiness      [2033-02-12 20:06:09+00:00]
# Discussion 5: Learner readiness for eLearning in the new era               [2033-02-12 20:06:09+00:00]
# Discussion 6: Organization & support                                       [2033-02-26 20:06:09+00:00]
# Discussion 7: eLearning planning at your institution?                      [2033-03-05 20:06:09+00:00]
# Discussion 8: Critical reflection on some institutional strategic plans    [2033-03-12 19:06:09+00:00]
# Discussion 9: Aligning institutional plans with government policies        [2033-03-19 19:06:09+00:00]
# Introduce yourself                                                         [2033-01-15 20:06:09+00:00]
# Q&A with Guest Speaker                                                     [2033-03-23 19:06:09+00:00]
# Name: todo_date_date, dtype: object

# %%
# post_count = full_table.groupby('Student')['post_id'].count()
# like_sum = full_table.groupby('Student')['count_of_likes'].sum()
# post_count_percent = pd.Series(scipy.stats.norm.cdf(post_count, np.mean(post_count), np.std(post_count)), index=post_count.index)

# pd.DataFrame(data =(post_count,like_sum, post_count_percent))
full_table.groupby('Student')['Current Score'].mean()
# Out:
# Student
# LEARNER_1     80.9
# LEARNER_10    78.4
# LEARNER_11    84.3
# LEARNER_12    81.2
# LEARNER_13    85.5
# LEARNER_14    84.4
# LEARNER_15    76.2
# LEARNER_16    82.0
# LEARNER_17    65.7
# LEARNER_18    69.7
# LEARNER_19    85.2
# LEARNER_2     84.6
# LEARNER_20    69.7
# LEARNER_21    78.5
# LEARNER_23    89.2
# LEARNER_24    86.4
# LEARNER_25    87.3
# LEARNER_26    87.5
# LEARNER_27    73.0
# LEARNER_29    85.7
# LEARNER_3     89.0
# LEARNER_30    78.3
# LEARNER_31    77.9
# LEARNER_33    72.1
# LEARNER_34    81.3
# LEARNER_35    79.1
# LEARNER_36    70.9
# LEARNER_37    82.3
# LEARNER_4     82.9
# LEARNER_5     88.0
# LEARNER_6     92.2
# LEARNER_7     87.3
# LEARNER_8     83.6
# Name: Current Score, dtype: float64

# %%
import datetime as dt



def discussion_summary(session_df, start_date, end_date):

    summary_df = session_df.copy(deep=True)

    summary_df = summary_df[(summary_df.timestamp.dt.date > start_date) & (summary_df.timestamp.dt.date < end_date)]

    post_count = summary_df.groupby('Student')['post_id'].count().rename('post_count')
    like_sum = summary_df.groupby('Student')['count_of_likes'].sum().rename('like_sum')
    message_sum = summary_df.groupby('Student')['post_message_length'].sum().rename('message_sum')
    message_mean = summary_df.groupby('Student')['post_message_length'].mean().rename('message_mean')
    course_grade = summary_df.groupby('Student')['Current Score'].mean().rename('current_score')

    post_count_percent = pd.Series(scipy.stats.norm.cdf(post_count, np.mean(post_count), np.std(post_count)), index=post_count.index).rename('post_count_percent')
    like_sum_percent = pd.Series(scipy.stats.norm.cdf(like_sum, np.mean(like_sum), np.std(like_sum)), index=like_sum.index ).rename('like_sum_percent')
    message_sum_percent = pd.Series(scipy.stats.norm.cdf(message_sum, np.mean(message_sum), np.std(message_sum)), index=message_sum.index).rename('message_sum_percent')


    results = pd.DataFrame(data =(post_count, post_count_percent, like_sum, like_sum_percent, message_sum, message_mean, message_sum_percent, course_grade)).T.reset_index()

    return results

start_date =  dt.date(2033, 2,25)
end_date =  dt.date(2033, 3,25)

discussion_summary(full_table, start_date, end_date)


test_vis = discussion_summary(full_table, start_date, end_date)

test_vis
# Out:
#        Student  post_count  post_count_percent  like_sum  like_sum_percent  \
# 0    LEARNER_1         3.0            0.207404       1.0          0.354908
# 1   LEARNER_10        12.0            0.593939       5.0          0.946568
# 2   LEARNER_11         6.0            0.321177       1.0          0.354908
# 3   LEARNER_12         7.0            0.364148       1.0          0.354908
# 4   LEARNER_13        14.0            0.681438       5.0          0.946568
# 5   LEARNER_14         6.0            0.321177       1.0          0.354908
# 6   LEARNER_15         3.0            0.207404       0.0          0.192631
# 7   LEARNER_16        17.0            0.794682       1.0          0.354908
# 8   LEARNER_17         2.0            0.175545       0.0          0.192631
# 9   LEARNER_18        15.0            0.721983       0.0          0.192631
# 10  LEARNER_19         8.0            0.408899       2.0          0.549356
# 11   LEARNER_2         6.0            0.321177       2.0          0.549356
# 12  LEARNER_20         6.0            0.321177       0.0          0.192631
# 13  LEARNER_21         3.0            0.207404       0.0          0.192631
# 14  LEARNER_23        16.0            0.759831       8.0          0.999035
# 15  LEARNER_24         9.0            0.454873       4.0          0.867856
# 16  LEARNER_25         7.0            0.364148       0.0          0.192631
# 17  LEARNER_26         5.0            0.280476       1.0          0.354908
# 18  LEARNER_29         6.0            0.321177       0.0          0.192631
# 19   LEARNER_3         8.0            0.408899       1.0          0.354908
# 20  LEARNER_30        11.0            0.548025       4.0          0.867856
# 21  LEARNER_31        11.0            0.548025       4.0          0.867856
# 22  LEARNER_33         5.0            0.280476       0.0          0.192631
# 23  LEARNER_34         9.0            0.454873       0.0          0.192631
# 24  LEARNER_35         6.0            0.321177       2.0          0.549356
# 25  LEARNER_36         3.0            0.207404       0.0          0.192631
# 26  LEARNER_37         4.0            0.242450       0.0          0.192631
# 27   LEARNER_4        29.0            0.987026       2.0          0.549356
# 28   LEARNER_5        18.0            0.826338       1.0          0.354908
# 29   LEARNER_6        45.0            0.999979       4.0          0.867856
# 30   LEARNER_7        16.0            0.759831       5.0          0.946568
# 31   LEARNER_8         3.0            0.207404       1.0          0.354908
#
#     message_sum  message_mean  message_sum_percent  current_score
# 0        6756.0   2252.000000             0.230049           80.9
# 1       13683.0   1140.250000             0.561791           78.4
# 2        5756.0    959.333333             0.192759           84.3
# 3        8403.0   1200.428571             0.299418           81.2
# 4       14112.0   1008.000000             0.583514           85.5
# 5       17299.0   2883.166667             0.733126           84.4
# 6        3240.0   1080.000000             0.116521           76.2
# 7       28471.0   1674.764706             0.980514           82.0
# 8        2352.0   1176.000000             0.095574           65.7
# 9       14735.0    982.333333             0.614594           69.7
# 10       8004.0   1000.500000             0.281773           85.2
# 11       8443.0   1407.166667             0.301214           84.6
# 12       7000.0   1166.666667             0.239725           69.7
# 13      11006.0   3668.666667             0.424632           78.5
# 14      20156.0   1259.750000             0.839182           89.2
# 15       8679.0    964.333333             0.311909           86.4
# 16       5570.0    795.714286             0.186254           87.3
# 17       6583.0   1316.600000             0.223323           87.5
# 18      12555.0   2092.500000             0.503949           85.7
# 19       7988.0    998.500000             0.281076           89.0
# 20      14613.0   1328.454545             0.608558           78.3
# 21      11285.0   1025.909091             0.438788           77.9
# 22       4396.0    879.200000             0.148397           72.1
# 23      11688.0   1298.666667             0.459370           81.3
# 24      13727.0   2287.833333             0.564029           79.1
# 25       6016.0   2005.333333             0.202081           70.9
# 26      15644.0   3911.000000             0.658603           82.3
# 27      24885.0    858.103448             0.945374           82.9
# 28      29516.0   1639.777778             0.986074           88.0
# 29      34533.0    767.400000             0.997793           92.2
# 30      15876.0    992.250000             0.669525           87.3
# 31       6336.0   2112.000000             0.213917           83.6

# %%
# likes per learner

alt.Chart(disc_merged).mark_bar().encode(
    alt.Y('actor_id', sort='x'),
    alt.X('count_of_likes')
)
# Out:
# /Users/jonah/opt/miniconda3/envs/571/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# post length per disscussion topic

alt.Chart(full_table).mark_bar().encode(
    alt.X('post_message_length'),
    alt.Y('title'),
    alt.Color('post_message_length')).facet('actor_id', columns=3)
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# likes per assignment

alt.Chart(disc_merged).mark_bar().encode(
    alt.Y('title', sort='x'),
    alt.X('count_of_likes')
)
# Out:
# /Users/jonah/opt/miniconda3/envs/571/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
full_table.dropna().groupby('Student')

# %%
alt.Chart(full_table.dropna()).mark_rect().encode(
    alt.X('Current Score', bin=alt.Bin(maxbins=50), title='Course grade'),
    alt.Y('post_message_length', bin=alt.Bin(maxbins=40), title='Message length'),
    alt.Color('count()', title='Number of Records'))
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(full_table).mark_circle().encode(
    alt.Y('mean(post_message_length)', title='Mean post length'),
    alt.X('Current Score'),
    alt.Color('Student'),
    tooltip='Student'
)
# Out:
# /Users/jonah/opt/miniconda3/envs/571/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
